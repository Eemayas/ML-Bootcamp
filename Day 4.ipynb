# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=np.linspace(0,5,11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.title(r"$y=x^2$")
plt.show()

# %%
plt.subplot?
# Out:
# Signature: plt.subplot(*args, **kwargs)
# Docstring:
# Add an Axes to the current figure or retrieve an existing Axes.
#
# This is a wrapper of `.Figure.add_subplot` which provides additional
# behavior when working with the implicit API (see the notes section).
#
# Call signatures::
#
#    subplot(nrows, ncols, index, **kwargs)
#    subplot(pos, **kwargs)
#    subplot(**kwargs)
#    subplot(ax)
#
# Parameters
# ----------
# *args : int, (int, int, *index*), or `.SubplotSpec`, default: (1, 1, 1)
#     The position of the subplot described by one of
#
#     - Three integers (*nrows*, *ncols*, *index*). The subplot will take the
#       *index* position on a grid with *nrows* rows and *ncols* columns.
#       *index* starts at 1 in the upper left corner and increases to the
#       right. *index* can also be a two-tuple specifying the (*first*,
#       *last*) indices (1-based, and including *last*) of the subplot, e.g.,
# ...

# %%
plt.subplot(1,2,2)
plt.xlabel("x")
plt.ylabel("x^z")
plt.plot(x,y,"r*:")
plt.title("Graph")
plt.subplot(1,2,1)
plt.xlabel("x")
plt.ylabel("x^z")
plt.plot(y,x,"g*:")
plt.title("Graph")
plt.tight_layout()
plt.show()

# %%
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,"g")
axes.set_xlabel("x")
axes.set_ylabel("y")
axes.set_title("Graph")
fig.show()
# Out:
# C:\Users\Helios\AppData\Local\Temp\ipykernel_13840\2912999920.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,1,1])
axes1=fig.add_axes([0.2,0.5,0.4,0.4])
axes.plot(x,y,"g")
axes.set_xlabel("x")
axes.set_ylabel("y")
axes.set_title("Graph")

axes1.plot(x,y,"g")
axes1.set_xlabel("x1")
axes1.set_ylabel("y2")
axes1.set_title("Graph")
fig.show()
# Out:
# C:\Users\Helios\AppData\Local\Temp\ipykernel_13840\4197496909.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.4,0.4])
axes1=fig.add_axes([0.1,0.6,0.4,0.4])
axes4=fig.add_axes([0.1,1.3,0.4,0.4])
axes4=fig.add_axes([0.1,1.7,0.4,0.4])
axes2=fig.add_axes([0.6,0.1,0.4,0.4])
axes2=fig.add_axes([0.6,0.6,0.4,0.4])
axes2=fig.add_axes([0.6,1.3,0.4,0.4])
axes3=fig.add_axes([0.6,1.7,0.4,0.4])
axes=fig.add_axes ([1.2,0.1,0.4,0.4])
axes1=fig.add_axes([1.2,0.6,0.4,0.4])
axes4=fig.add_axes([1.2,1.3,0.4,0.4])
axes4=fig.add_axes([1.2,1.7,0.4,0.4])
axes2=fig.add_axes([1.7,0.1,0.4,0.4])
axes2=fig.add_axes([1.7,0.6,0.4,0.4])
axes2=fig.add_axes([1.7,1.3,0.4,0.4])
axes3=fig.add_axes([1.7,1.7,0.4,0.4])

fig.show()
# Out:
# C:\Users\Helios\AppData\Local\Temp\ipykernel_13840\3685661699.py:19: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
figs, axes = plt.subplots(nrows=3, ncols=3)

# %%
fig = plt.figure(figsize=(8,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x, x**2, label="x**2")
ax.plot(x, x**3, label="x**3")
ax.legend()
